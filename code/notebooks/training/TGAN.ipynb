# %%
import os
os.chdir('../..')

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.9

# %%
import numpy as np
import pandas as pd

from tgan.model import TGANModel

# For the Python notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# Out:
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\hooks.py:17: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\optimizer.py:18: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:20: The name tf.train.SessionCreator is deprecated. Please use tf.compat.v1.train.SessionCreator instead.

# %%
dataset = 'LPMC'

# %%
df = pd.read_csv('../data/{}/data.csv'.format(dataset), index_col=False)

# %%
len(df.columns)
# Out:
# 28

# %%
df.head()
# Out:
#   travel_mode purpose    fueltype faretype  bus_scale  survey_year  \
# 0       drive     HBO  Petrol_Car     full        1.0            1
# 1       drive     HBO  Petrol_Car     full        1.0            1
# 2       drive     HBO  Petrol_Car     full        1.0            1
# 3       drive     HBO  Petrol_Car     full        1.0            1
# 4       drive     HBO  Petrol_Car      dis        1.0            1
#
#    travel_year  travel_month  travel_date  day_of_week  ...  dur_pt_access  \
# 0         2012             4            1            7  ...       0.134444
# 1         2012             4            1            7  ...       0.109444
# 2         2012             4            1            7  ...       0.203056
# 3         2012             4            1            7  ...       0.205556
# 4         2012             4            1            7  ...       0.203056
#
#    dur_pt_rail  dur_pt_bus  dur_pt_int  pt_n_interchanges  dur_driving  \
# 0          0.0    0.016667         0.0                  0     0.052222
# 1          0.0    0.055556         0.0                  0     0.059444
# 2          0.0    0.210278         0.0                  0     0.236667
# 3          0.0    0.258611         0.0                  0     0.233333
# 4          0.0    0.189444         0.0                  0     0.229167
#
#    cost_transit  cost_driving_fuel  cost_driving_con_charge  \
# 0           1.5               0.14                      0.0
# 1           1.5               0.15                      0.0
# 2           1.5               0.79                      0.0
# 3           1.5               0.78                      0.0
# 4           1.5               0.78                      0.0
#
#    driving_traffic_percent
# 0                 0.111702
# 1                 0.112150
# 2                 0.203052
# 3                 0.160714
# 4                 0.130909
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['travel_mode', 'purpose', 'fueltype', 'faretype', 'bus_scale',
#        'survey_year', 'travel_year', 'travel_month', 'travel_date',
#        'day_of_week', 'start_time_linear', 'age', 'female', 'driving_license',
#        'car_ownership', 'distance', 'dur_walking', 'dur_cycling',
#        'dur_pt_access', 'dur_pt_rail', 'dur_pt_bus', 'dur_pt_int',
#        'pt_n_interchanges', 'dur_driving', 'cost_transit', 'cost_driving_fuel',
#        'cost_driving_con_charge', 'driving_traffic_percent'],
#       dtype='object')

# %%
for j,i in enumerate(df.columns):
    if len(df[i].unique()) > 10:
        print('{} - {}: {}'.format(j, i, len(df[i].unique())))
# Out:
# 7 - travel_month: 12
# 8 - travel_date: 31
# 10 - start_time_linear: 965
# 11 - age: 91
# 15 - distance: 13533
# 16 - dur_walking: 13997
# 17 - dur_cycling: 5924
# 18 - dur_pt_access: 1932
# 19 - dur_pt_rail: 82
# 20 - dur_pt_bus: 3321
# 21 - dur_pt_int: 1076
# 23 - dur_driving: 4560
# 24 - cost_transit: 184
# 25 - cost_driving_fuel: 617
# 27 - driving_traffic_percent: 50923

# %%
if dataset is 'Chicago':
    continuous_columns = [3, 10, 14]
elif dataset is 'LPMC':
    continuous_columns = [10, 11, 15, 16, 17, 18, 19, 20, 21, 23, 24, 25, 27]

# %%
output_folder = '../output/' + dataset + '/TGAN2/'

# %%
tgan = TGANModel(continuous_columns, max_epoch=1000, steps_per_epoch=2000, batch_size=200, output=output_folder, gpu=0)

# %%
tgan.fit(df)
# Out:
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\graph_builder\model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\graph_builder\model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\input_source\input_source.py:219: The name tf.FIFOQueue is deprecated. Please use tf.queue.FIFOQueue instead.
#
# [0912 18:27:14 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\summary.py:237: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\summary.py:27: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\summary.py:254: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\summary.py:264: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\collection.py:105: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\collection.py:33: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:455: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:458: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:259: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [0912 18:27:14 @registry.py:126] gen/LSTM/00/FC input: [200, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\fc.py:57: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\fc.py:67: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# [0912 18:27:14 @registry.py:134] gen/LSTM/00/FC output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/00/FC2 input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/00/FC2 output: [200, 4]
# [0912 18:27:14 @registry.py:126] gen/LSTM/00/FC3 input: [200, 4]
# [0912 18:27:14 @registry.py:134] gen/LSTM/00/FC3 output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/01/FC input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/01/FC output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/01/FC2 input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/01/FC2 output: [200, 5]
# [0912 18:27:14 @registry.py:126] gen/LSTM/01/FC3 input: [200, 5]
# [0912 18:27:14 @registry.py:134] gen/LSTM/01/FC3 output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/02/FC input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/02/FC output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/02/FC2 input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/02/FC2 output: [200, 6]
# [0912 18:27:14 @registry.py:126] gen/LSTM/02/FC3 input: [200, 6]
# [0912 18:27:14 @registry.py:134] gen/LSTM/02/FC3 output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/03/FC input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/03/FC output: [200, 100]
# [0912 18:27:14 @registry.py:126] gen/LSTM/03/FC2 input: [200, 100]
# [0912 18:27:14 @registry.py:134] gen/LSTM/03/FC2 output: [200, 5]
# [0912 18:27:14 @registry.py:126] gen/LSTM/03/FC3 input: [200, 5]
# [0912 18:27:15 @registry.py:134] gen/LSTM/03/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/04/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/04/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/04/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/04/FC2 output: [200, 3]
# [0912 18:27:15 @registry.py:126] gen/LSTM/04/FC3 input: [200, 3]
# [0912 18:27:15 @registry.py:134] gen/LSTM/04/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/05/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/05/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/05/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/05/FC2 output: [200, 3]
# [0912 18:27:15 @registry.py:126] gen/LSTM/05/FC3 input: [200, 3]
# [0912 18:27:15 @registry.py:134] gen/LSTM/05/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/06/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/06/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/06/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/06/FC2 output: [200, 4]
# [0912 18:27:15 @registry.py:126] gen/LSTM/06/FC3 input: [200, 4]
# [0912 18:27:15 @registry.py:134] gen/LSTM/06/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/07/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/07/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/07/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/07/FC2 output: [200, 12]
# [0912 18:27:15 @registry.py:126] gen/LSTM/07/FC3 input: [200, 12]
# [0912 18:27:15 @registry.py:134] gen/LSTM/07/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/08/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/08/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/08/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/08/FC2 output: [200, 31]
# [0912 18:27:15 @registry.py:126] gen/LSTM/08/FC3 input: [200, 31]
# [0912 18:27:15 @registry.py:134] gen/LSTM/08/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/09/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/09/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/09/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/09/FC2 output: [200, 7]
# [0912 18:27:15 @registry.py:126] gen/LSTM/09/FC3 input: [200, 7]
# [0912 18:27:15 @registry.py:134] gen/LSTM/09/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/10/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/10/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/10/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/10/FC2 output: [200, 1]
# [0912 18:27:15 @registry.py:126] gen/LSTM/11/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/11/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/11/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/11/FC2 output: [200, 5]
# [0912 18:27:15 @registry.py:126] gen/LSTM/11/FC3 input: [200, 5]
# [0912 18:27:15 @registry.py:134] gen/LSTM/11/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/12/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/12/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/12/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/12/FC2 output: [200, 1]
# [0912 18:27:15 @registry.py:126] gen/LSTM/13/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/13/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/13/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/13/FC2 output: [200, 5]
# [0912 18:27:15 @registry.py:126] gen/LSTM/13/FC3 input: [200, 5]
# [0912 18:27:15 @registry.py:134] gen/LSTM/13/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/14/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/14/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/14/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/14/FC2 output: [200, 2]
# [0912 18:27:15 @registry.py:126] gen/LSTM/14/FC3 input: [200, 2]
# [0912 18:27:15 @registry.py:134] gen/LSTM/14/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/15/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/15/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/15/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/15/FC2 output: [200, 2]
# [0912 18:27:15 @registry.py:126] gen/LSTM/15/FC3 input: [200, 2]
# [0912 18:27:15 @registry.py:134] gen/LSTM/15/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/16/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/16/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/16/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/16/FC2 output: [200, 3]
# [0912 18:27:15 @registry.py:126] gen/LSTM/16/FC3 input: [200, 3]
# [0912 18:27:15 @registry.py:134] gen/LSTM/16/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/17/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/17/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/17/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/17/FC2 output: [200, 1]
# [0912 18:27:15 @registry.py:126] gen/LSTM/18/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/18/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/18/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/18/FC2 output: [200, 5]
# [0912 18:27:15 @registry.py:126] gen/LSTM/18/FC3 input: [200, 5]
# [0912 18:27:15 @registry.py:134] gen/LSTM/18/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/19/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/19/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/19/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/19/FC2 output: [200, 1]
# [0912 18:27:15 @registry.py:126] gen/LSTM/20/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/20/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/20/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/20/FC2 output: [200, 5]
# [0912 18:27:15 @registry.py:126] gen/LSTM/20/FC3 input: [200, 5]
# [0912 18:27:15 @registry.py:134] gen/LSTM/20/FC3 output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/21/FC input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/21/FC output: [200, 100]
# [0912 18:27:15 @registry.py:126] gen/LSTM/21/FC2 input: [200, 100]
# [0912 18:27:15 @registry.py:134] gen/LSTM/21/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/22/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/22/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/22/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/22/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/22/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/22/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/23/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/23/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/23/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/23/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/24/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/24/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/24/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/24/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/24/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/24/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/25/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/25/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/25/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/25/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/26/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/26/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/26/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/26/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/26/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/26/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/27/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/27/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/27/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/27/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/28/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/28/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/28/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/28/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/28/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/28/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/29/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/29/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/29/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/29/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/30/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/30/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/30/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/30/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/30/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/30/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/31/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/31/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/31/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/31/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/31/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/31/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/32/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/32/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/32/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/32/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/33/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/33/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/33/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/33/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/33/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/33/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/34/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/34/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/34/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/34/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/35/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/35/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/35/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/35/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/35/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/35/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/36/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/36/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/36/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/36/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/37/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/37/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/37/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/37/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/37/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/37/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/38/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/38/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/38/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/38/FC2 output: [200, 2]
# [0912 18:27:16 @registry.py:126] gen/LSTM/38/FC3 input: [200, 2]
# [0912 18:27:16 @registry.py:134] gen/LSTM/38/FC3 output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/39/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/39/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/39/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/39/FC2 output: [200, 1]
# [0912 18:27:16 @registry.py:126] gen/LSTM/40/FC input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/40/FC output: [200, 100]
# [0912 18:27:16 @registry.py:126] gen/LSTM/40/FC2 input: [200, 100]
# [0912 18:27:16 @registry.py:134] gen/LSTM/40/FC2 output: [200, 5]
# [0912 18:27:16 @registry.py:126] gen/LSTM/40/FC3 input: [200, 5]
# [0912 18:27:16 @registry.py:134] gen/LSTM/40/FC3 output: [200, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:494: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:443: The name tf.log is deprecated. Please use tf.math.log instead.
#
# [0912 18:27:17 @registry.py:126] discrim/dis_fc0/fc input: [200, 172]
# [0912 18:27:17 @registry.py:134] discrim/dis_fc0/fc output: [200, 100]
# [0912 18:27:17 @registry.py:126] discrim/dis_fc0/fc_diversity input: [200, 100]
# [0912 18:27:17 @registry.py:134] discrim/dis_fc0/fc_diversity output: [200, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\batch_norm.py:204: The name tf.layers.BatchNormalization is deprecated. Please use tf.compat.v1.layers.BatchNormalization instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\batch_norm.py:212: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# [0912 18:27:17 @registry.py:126] discrim/dis_fc_top input: [200, 110]
# [0912 18:27:17 @registry.py:134] discrim/dis_fc_top output: [200, 1]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:118: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py:551: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# [0912 18:27:23 @logger.py:90] Argv: D:\Users\glede\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py -f C:\Users\glede\AppData\Roaming\jupyter\runtime\kernel-b050de30-498b-424d-8e40-89baab2b9565.json
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\saver.py:43: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\saver.py:44: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:41: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# [0912 18:27:23 @model_utils.py:67] List of Trainable Variables:
# name                              shape         #elements
# --------------------------------  ----------  -----------
# gen/LSTM/go:0                     [1, 100]            100
# gen/LSTM/lstm_cell/kernel:0       [500, 400]       200000
# gen/LSTM/lstm_cell/bias:0         [400]               400
# gen/LSTM/00/FC/W:0                [100, 100]        10000
# gen/LSTM/00/FC/b:0                [100]               100
# gen/LSTM/00/FC2/W:0               [100, 4]            400
# gen/LSTM/00/FC2/b:0               [4]                   4
# gen/LSTM/00/FC3/W:0               [4, 100]            400
# gen/LSTM/00/FC3/b:0               [100]               100
# gen/LSTM/00/attw:0                [1, 1, 1]             1
# gen/LSTM/01/FC/W:0                [100, 100]        10000
# gen/LSTM/01/FC/b:0                [100]               100
# gen/LSTM/01/FC2/W:0               [100, 5]            500
# gen/LSTM/01/FC2/b:0               [5]                   5
# gen/LSTM/01/FC3/W:0               [5, 100]            500
# gen/LSTM/01/FC3/b:0               [100]               100
# gen/LSTM/01/attw:0                [2, 1, 1]             2
# gen/LSTM/02/FC/W:0                [100, 100]        10000
# gen/LSTM/02/FC/b:0                [100]               100
# gen/LSTM/02/FC2/W:0               [100, 6]            600
# gen/LSTM/02/FC2/b:0               [6]                   6
# gen/LSTM/02/FC3/W:0               [6, 100]            600
# gen/LSTM/02/FC3/b:0               [100]               100
# gen/LSTM/02/attw:0                [3, 1, 1]             3
# gen/LSTM/03/FC/W:0                [100, 100]        10000
# gen/LSTM/03/FC/b:0                [100]               100
# gen/LSTM/03/FC2/W:0               [100, 5]            500
# gen/LSTM/03/FC2/b:0               [5]                   5
# gen/LSTM/03/FC3/W:0               [5, 100]            500
# gen/LSTM/03/FC3/b:0               [100]               100
# gen/LSTM/03/attw:0                [4, 1, 1]             4
# gen/LSTM/04/FC/W:0                [100, 100]        10000
# gen/LSTM/04/FC/b:0                [100]               100
# gen/LSTM/04/FC2/W:0               [100, 3]            300
# gen/LSTM/04/FC2/b:0               [3]                   3
# gen/LSTM/04/FC3/W:0               [3, 100]            300
# gen/LSTM/04/FC3/b:0               [100]               100
# gen/LSTM/04/attw:0                [5, 1, 1]             5
# gen/LSTM/05/FC/W:0                [100, 100]        10000
# gen/LSTM/05/FC/b:0                [100]               100
# gen/LSTM/05/FC2/W:0               [100, 3]            300
# gen/LSTM/05/FC2/b:0               [3]                   3
# gen/LSTM/05/FC3/W:0               [3, 100]            300
# gen/LSTM/05/FC3/b:0               [100]               100
# gen/LSTM/05/attw:0                [6, 1, 1]             6
# gen/LSTM/06/FC/W:0                [100, 100]        10000
# gen/LSTM/06/FC/b:0                [100]               100
# gen/LSTM/06/FC2/W:0               [100, 4]            400
# gen/LSTM/06/FC2/b:0               [4]                   4
# gen/LSTM/06/FC3/W:0               [4, 100]            400
# gen/LSTM/06/FC3/b:0               [100]               100
# gen/LSTM/06/attw:0                [7, 1, 1]             7
# gen/LSTM/07/FC/W:0                [100, 100]        10000
# gen/LSTM/07/FC/b:0                [100]               100
# gen/LSTM/07/FC2/W:0               [100, 12]          1200
# gen/LSTM/07/FC2/b:0               [12]                 12
# gen/LSTM/07/FC3/W:0               [12, 100]          1200
# gen/LSTM/07/FC3/b:0               [100]               100
# gen/LSTM/07/attw:0                [8, 1, 1]             8
# gen/LSTM/08/FC/W:0                [100, 100]        10000
# gen/LSTM/08/FC/b:0                [100]               100
# gen/LSTM/08/FC2/W:0               [100, 31]          3100
# gen/LSTM/08/FC2/b:0               [31]                 31
# gen/LSTM/08/FC3/W:0               [31, 100]          3100
# gen/LSTM/08/FC3/b:0               [100]               100
# gen/LSTM/08/attw:0                [9, 1, 1]             9
# gen/LSTM/09/FC/W:0                [100, 100]        10000
# gen/LSTM/09/FC/b:0                [100]               100
# gen/LSTM/09/FC2/W:0               [100, 7]            700
# gen/LSTM/09/FC2/b:0               [7]                   7
# gen/LSTM/09/FC3/W:0               [7, 100]            700
# gen/LSTM/09/FC3/b:0               [100]               100
# gen/LSTM/09/attw:0                [10, 1, 1]           10
# gen/LSTM/10/FC/W:0                [100, 100]        10000
# gen/LSTM/10/FC/b:0                [100]               100
# gen/LSTM/10/FC2/W:0               [100, 1]            100
# gen/LSTM/10/FC2/b:0               [1]                   1
# gen/LSTM/10/attw:0                [11, 1, 1]           11
# gen/LSTM/11/FC/W:0                [100, 100]        10000
# gen/LSTM/11/FC/b:0                [100]               100
# gen/LSTM/11/FC2/W:0               [100, 5]            500
# gen/LSTM/11/FC2/b:0               [5]                   5
# gen/LSTM/11/FC3/W:0               [5, 100]            500
# gen/LSTM/11/FC3/b:0               [100]               100
# gen/LSTM/11/attw:0                [12, 1, 1]           12
# gen/LSTM/12/FC/W:0                [100, 100]        10000
# gen/LSTM/12/FC/b:0                [100]               100
# gen/LSTM/12/FC2/W:0               [100, 1]            100
# gen/LSTM/12/FC2/b:0               [1]                   1
# gen/LSTM/12/attw:0                [13, 1, 1]           13
# gen/LSTM/13/FC/W:0                [100, 100]        10000
# gen/LSTM/13/FC/b:0                [100]               100
# gen/LSTM/13/FC2/W:0               [100, 5]            500
# gen/LSTM/13/FC2/b:0               [5]                   5
# gen/LSTM/13/FC3/W:0               [5, 100]            500
# gen/LSTM/13/FC3/b:0               [100]               100
# gen/LSTM/13/attw:0                [14, 1, 1]           14
# gen/LSTM/14/FC/W:0                [100, 100]        10000
# gen/LSTM/14/FC/b:0                [100]               100
# gen/LSTM/14/FC2/W:0               [100, 2]            200
# gen/LSTM/14/FC2/b:0               [2]                   2
# gen/LSTM/14/FC3/W:0               [2, 100]            200
# gen/LSTM/14/FC3/b:0               [100]               100
# gen/LSTM/14/attw:0                [15, 1, 1]           15
# gen/LSTM/15/FC/W:0                [100, 100]        10000
# gen/LSTM/15/FC/b:0                [100]               100
# gen/LSTM/15/FC2/W:0               [100, 2]            200
# gen/LSTM/15/FC2/b:0               [2]                   2
# gen/LSTM/15/FC3/W:0               [2, 100]            200
# gen/LSTM/15/FC3/b:0               [100]               100
# gen/LSTM/15/attw:0                [16, 1, 1]           16
# gen/LSTM/16/FC/W:0                [100, 100]        10000
# gen/LSTM/16/FC/b:0                [100]               100
# gen/LSTM/16/FC2/W:0               [100, 3]            300
# gen/LSTM/16/FC2/b:0               [3]                   3
# gen/LSTM/16/FC3/W:0               [3, 100]            300
# gen/LSTM/16/FC3/b:0               [100]               100
# gen/LSTM/16/attw:0                [17, 1, 1]           17
# gen/LSTM/17/FC/W:0                [100, 100]        10000
# gen/LSTM/17/FC/b:0                [100]               100
# gen/LSTM/17/FC2/W:0               [100, 1]            100
# gen/LSTM/17/FC2/b:0               [1]                   1
# gen/LSTM/17/attw:0                [18, 1, 1]           18
# gen/LSTM/18/FC/W:0                [100, 100]        10000
# gen/LSTM/18/FC/b:0                [100]               100
# gen/LSTM/18/FC2/W:0               [100, 5]            500
# gen/LSTM/18/FC2/b:0               [5]                   5
# gen/LSTM/18/FC3/W:0               [5, 100]            500
# gen/LSTM/18/FC3/b:0               [100]               100
# gen/LSTM/18/attw:0                [19, 1, 1]           19
# gen/LSTM/19/FC/W:0                [100, 100]        10000
# gen/LSTM/19/FC/b:0                [100]               100
# gen/LSTM/19/FC2/W:0               [100, 1]            100
# gen/LSTM/19/FC2/b:0               [1]                   1
# gen/LSTM/19/attw:0                [20, 1, 1]           20
# gen/LSTM/20/FC/W:0                [100, 100]        10000
# gen/LSTM/20/FC/b:0                [100]               100
# gen/LSTM/20/FC2/W:0               [100, 5]            500
# gen/LSTM/20/FC2/b:0               [5]                   5
# gen/LSTM/20/FC3/W:0               [5, 100]            500
# gen/LSTM/20/FC3/b:0               [100]               100
# gen/LSTM/20/attw:0                [21, 1, 1]           21
# gen/LSTM/21/FC/W:0                [100, 100]        10000
# gen/LSTM/21/FC/b:0                [100]               100
# gen/LSTM/21/FC2/W:0               [100, 1]            100
# gen/LSTM/21/FC2/b:0               [1]                   1
# gen/LSTM/21/attw:0                [22, 1, 1]           22
# gen/LSTM/22/FC/W:0                [100, 100]        10000
# gen/LSTM/22/FC/b:0                [100]               100
# gen/LSTM/22/FC2/W:0               [100, 5]            500
# gen/LSTM/22/FC2/b:0               [5]                   5
# gen/LSTM/22/FC3/W:0               [5, 100]            500
# gen/LSTM/22/FC3/b:0               [100]               100
# gen/LSTM/22/attw:0                [23, 1, 1]           23
# gen/LSTM/23/FC/W:0                [100, 100]        10000
# gen/LSTM/23/FC/b:0                [100]               100
# gen/LSTM/23/FC2/W:0               [100, 1]            100
# gen/LSTM/23/FC2/b:0               [1]                   1
# gen/LSTM/23/attw:0                [24, 1, 1]           24
# gen/LSTM/24/FC/W:0                [100, 100]        10000
# gen/LSTM/24/FC/b:0                [100]               100
# gen/LSTM/24/FC2/W:0               [100, 5]            500
# gen/LSTM/24/FC2/b:0               [5]                   5
# gen/LSTM/24/FC3/W:0               [5, 100]            500
# gen/LSTM/24/FC3/b:0               [100]               100
# gen/LSTM/24/attw:0                [25, 1, 1]           25
# gen/LSTM/25/FC/W:0                [100, 100]        10000
# gen/LSTM/25/FC/b:0                [100]               100
# gen/LSTM/25/FC2/W:0               [100, 1]            100
# gen/LSTM/25/FC2/b:0               [1]                   1
# gen/LSTM/25/attw:0                [26, 1, 1]           26
# gen/LSTM/26/FC/W:0                [100, 100]        10000
# gen/LSTM/26/FC/b:0                [100]               100
# gen/LSTM/26/FC2/W:0               [100, 5]            500
# gen/LSTM/26/FC2/b:0               [5]                   5
# gen/LSTM/26/FC3/W:0               [5, 100]            500
# gen/LSTM/26/FC3/b:0               [100]               100
# gen/LSTM/26/attw:0                [27, 1, 1]           27
# gen/LSTM/27/FC/W:0                [100, 100]        10000
# gen/LSTM/27/FC/b:0                [100]               100
# gen/LSTM/27/FC2/W:0               [100, 1]            100
# gen/LSTM/27/FC2/b:0               [1]                   1
# gen/LSTM/27/attw:0                [28, 1, 1]           28
# gen/LSTM/28/FC/W:0                [100, 100]        10000
# gen/LSTM/28/FC/b:0                [100]               100
# gen/LSTM/28/FC2/W:0               [100, 5]            500
# gen/LSTM/28/FC2/b:0               [5]                   5
# gen/LSTM/28/FC3/W:0               [5, 100]            500
# gen/LSTM/28/FC3/b:0               [100]               100
# gen/LSTM/28/attw:0                [29, 1, 1]           29
# gen/LSTM/29/FC/W:0                [100, 100]        10000
# gen/LSTM/29/FC/b:0                [100]               100
# gen/LSTM/29/FC2/W:0               [100, 1]            100
# gen/LSTM/29/FC2/b:0               [1]                   1
# gen/LSTM/29/attw:0                [30, 1, 1]           30
# gen/LSTM/30/FC/W:0                [100, 100]        10000
# gen/LSTM/30/FC/b:0                [100]               100
# gen/LSTM/30/FC2/W:0               [100, 5]            500
# gen/LSTM/30/FC2/b:0               [5]                   5
# gen/LSTM/30/FC3/W:0               [5, 100]            500
# gen/LSTM/30/FC3/b:0               [100]               100
# gen/LSTM/30/attw:0                [31, 1, 1]           31
# gen/LSTM/31/FC/W:0                [100, 100]        10000
# gen/LSTM/31/FC/b:0                [100]               100
# gen/LSTM/31/FC2/W:0               [100, 5]            500
# gen/LSTM/31/FC2/b:0               [5]                   5
# gen/LSTM/31/FC3/W:0               [5, 100]            500
# gen/LSTM/31/FC3/b:0               [100]               100
# gen/LSTM/31/attw:0                [32, 1, 1]           32
# gen/LSTM/32/FC/W:0                [100, 100]        10000
# gen/LSTM/32/FC/b:0                [100]               100
# gen/LSTM/32/FC2/W:0               [100, 1]            100
# gen/LSTM/32/FC2/b:0               [1]                   1
# gen/LSTM/32/attw:0                [33, 1, 1]           33
# gen/LSTM/33/FC/W:0                [100, 100]        10000
# gen/LSTM/33/FC/b:0                [100]               100
# gen/LSTM/33/FC2/W:0               [100, 5]            500
# gen/LSTM/33/FC2/b:0               [5]                   5
# gen/LSTM/33/FC3/W:0               [5, 100]            500
# gen/LSTM/33/FC3/b:0               [100]               100
# gen/LSTM/33/attw:0                [34, 1, 1]           34
# gen/LSTM/34/FC/W:0                [100, 100]        10000
# gen/LSTM/34/FC/b:0                [100]               100
# gen/LSTM/34/FC2/W:0               [100, 1]            100
# gen/LSTM/34/FC2/b:0               [1]                   1
# gen/LSTM/34/attw:0                [35, 1, 1]           35
# gen/LSTM/35/FC/W:0                [100, 100]        10000
# gen/LSTM/35/FC/b:0                [100]               100
# gen/LSTM/35/FC2/W:0               [100, 5]            500
# gen/LSTM/35/FC2/b:0               [5]                   5
# gen/LSTM/35/FC3/W:0               [5, 100]            500
# gen/LSTM/35/FC3/b:0               [100]               100
# gen/LSTM/35/attw:0                [36, 1, 1]           36
# gen/LSTM/36/FC/W:0                [100, 100]        10000
# gen/LSTM/36/FC/b:0                [100]               100
# gen/LSTM/36/FC2/W:0               [100, 1]            100
# gen/LSTM/36/FC2/b:0               [1]                   1
# gen/LSTM/36/attw:0                [37, 1, 1]           37
# gen/LSTM/37/FC/W:0                [100, 100]        10000
# gen/LSTM/37/FC/b:0                [100]               100
# gen/LSTM/37/FC2/W:0               [100, 5]            500
# gen/LSTM/37/FC2/b:0               [5]                   5
# gen/LSTM/37/FC3/W:0               [5, 100]            500
# gen/LSTM/37/FC3/b:0               [100]               100
# gen/LSTM/37/attw:0                [38, 1, 1]           38
# gen/LSTM/38/FC/W:0                [100, 100]        10000
# gen/LSTM/38/FC/b:0                [100]               100
# gen/LSTM/38/FC2/W:0               [100, 2]            200
# gen/LSTM/38/FC2/b:0               [2]                   2
# gen/LSTM/38/FC3/W:0               [2, 100]            200
# gen/LSTM/38/FC3/b:0               [100]               100
# gen/LSTM/38/attw:0                [39, 1, 1]           39
# gen/LSTM/39/FC/W:0                [100, 100]        10000
# gen/LSTM/39/FC/b:0                [100]               100
# gen/LSTM/39/FC2/W:0               [100, 1]            100
# gen/LSTM/39/FC2/b:0               [1]                   1
# gen/LSTM/39/attw:0                [40, 1, 1]           40
# gen/LSTM/40/FC/W:0                [100, 100]        10000
# gen/LSTM/40/FC/b:0                [100]               100
# gen/LSTM/40/FC2/W:0               [100, 5]            500
# gen/LSTM/40/FC2/b:0               [5]                   5
# gen/LSTM/40/FC3/W:0               [5, 100]            500
# gen/LSTM/40/FC3/b:0               [100]               100
# gen/LSTM/40/attw:0                [41, 1, 1]           41
# discrim/dis_fc0/fc/W:0            [172, 100]        17200
# discrim/dis_fc0/fc/b:0            [100]               100
# discrim/dis_fc0/fc_diversity/W:0  [100, 100]        10000
# discrim/dis_fc0/fc_diversity/b:0  [100]               100
# discrim/dis_fc0/bn/beta:0         [110]               110
# discrim/dis_fc_top/W:0            [110, 1]            110
# discrim/dis_fc_top/b:0            [1]                   1
# Number of trainable variables: 271
# Number of parameters (elements): 679154
# Storage space needed for all trainable variables: 2.59MB
# [0912 18:27:23 @base.py:209] Setup callbacks graph ...
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\graph.py:54: The name tf.train.SessionRunArgs is deprecated. Please use tf.estimator.SessionRunArgs instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:75: The name tf.VariableScope is deprecated. Please use tf.compat.v1.VariableScope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:77: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\steps.py:117: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\saver.py:55: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\saver.py:59: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
#
# [0912 18:27:24 @summary.py:46] [MovingAverageSummary] 6 operations in collection 'MOVING_SUMMARY_OPS' will be run with session hooks.
# [0912 18:27:24 @summary.py:93] Summarizing collection 'summaries' of size 9.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\summary.py:94: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# [0912 18:27:24 @graph.py:98] Applying collection UPDATE_OPS of 4 ops.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\monitor.py:261: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# [0912 18:27:25 @base.py:230] Creating the session ...
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:42: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:71: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:72: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:73: The name tf.tables_initializer is deprecated. Please use tf.compat.v1.tables_initializer instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\train\base.py:254: The name tf.train.MonitoredSession is deprecated. Please use tf.compat.v1.train.MonitoredSession instead.
#
# [0912 18:27:28 @base.py:236] Initializing the session ...
# [0912 18:27:28 @base.py:243] Graph Finalized.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:89: The name tf.train.global_step is deprecated. Please use tf.compat.v1.train.global_step instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:90: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# [0912 18:27:28 @concurrency.py:38] Starting EnqueueThread QueueInput/input_queue ...
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\monitor.py:309: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# [0912 18:27:29 @base.py:275] Start Epoch 1 ...
#  64%|####################################################1                            |1287/2000[00:44<00:22,31.43it/s]
# [0912 18:28:14 @base.py:293] Detected Ctrl-C and exiting main loop.
#  65%|####################################################2                            |1291/2000[00:45<00:24,28.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8f8c6b1463b0> in <module>
# ----> 1 tgan.fit(df)
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tgan\model.py in fit(self, data)
#     714             max_epoch=self.max_epoch,
#     715             session_init=session_init,
# --> 716             starting_epoch=starting_epoch
#     717         )
#     718
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\train\base.py in train_with_defaults(self, _sentinel, callbacks, monitors, session_creator, session_init, steps_per_epoch, starting_epoch, max_epoch, extra_callbacks)
#     342         self.train(callbacks, monitors,
#     343                    session_creator, session_init,
# --> 344                    steps_per_epoch, starting_epoch, max_epoch)
#     345
#     346     def __new__(cls, *args, **kwargs):
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\train\base.py in train(self, callbacks, monitors, session_creator, session_init, steps_per_epoch, starting_epoch, max_epoch)
#     314         self.setup_callbacks(callbacks, monitors)
#     315         self.initialize(session_creator, session_init)
# --> 316         self.main_loop(steps_per_epoch, starting_epoch, max_epoch)
#     317
#     318     def train_with_defaults(
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\utils\argtools.py in wrapper(*args, **kwargs)
#     174         cache.add(func)
#     175
# --> 176         return func(*args, **kwargs)
#     177
#     178     return wrapper
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\train\base.py in main_loop(self, steps_per_epoch, starting_epoch, max_epoch)
#     279                         if self.hooked_sess.should_stop():
#     280                             return
# --> 281                         self.run_step()  # implemented by subclass
#     282                         self._callbacks.trigger_step()
#     283                     self._callbacks.after_epoch()
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\train\base.py in run_step(self)
#     179                 "Please either set `Trainer.train_op` or provide an implementation "
#     180                 "of Trainer.run_step()!")
# --> 181         self.hooked_sess.run(self.train_op)
#     182
#     183     @call_only_once
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1257             feed_dict=feed_dict,
#    1258             options=options,
# -> 1259             run_metadata=run_metadata)
#    1260       except _PREEMPTION_ERRORS as e:
#    1261         logging.info(
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, *args, **kwargs)
#    1343   def run(self, *args, **kwargs):
#    1344     try:
# -> 1345       return self._sess.run(*args, **kwargs)
#    1346     except _PREEMPTION_ERRORS:
#    1347       raise
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1416         feed_dict=feed_dict,
#    1417         options=options,
# -> 1418         run_metadata=run_metadata)
#    1419
#    1420     for hook in self._hooks:
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\training\monitored_session.py in run(self, *args, **kwargs)
#    1174
#    1175   def run(self, *args, **kwargs):
# -> 1176     return self._sess.run(*args, **kwargs)
#    1177
#    1178   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
tgan.save(output_folder + 'trained', force=True)
# Out:
# [0809 15:13:09 @model.py:813] Model saved successfully.
