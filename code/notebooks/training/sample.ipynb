# %%
import os
os.chdir('../..')

# %%
from platform import python_version

print(python_version())

# %%
import numpy as np
import pandas as pd
import json

import matplotlib.pyplot as plt

# For the Python notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
dataset = 'Chicago'
name = 'SGAN_OR'

# %%
df = pd.read_csv('../data/' + dataset + '/data.csv')

# %%
input_folder = '../output/' + dataset + '/'
output_folder = '../synth_data/' + dataset + '/'

# %%
if name not in os.listdir(input_folder):
    raise ValueError("Name of the model unknown!")

# %%
model = None
if name is 'CTGAN':
    import ctgan
    from ctgan import CTGANSynthesizer
    
    ctgan = CTGANSynthesizer()
    model = ctgan.load(input_folder + 'CTGAN/trained.pkl')
    
elif name is 'TGAN':
    from tgan.model import TGANModel
    model = TGANModel.load(input_folder + name + '/trained')
else:
    
    LIB = None
        
    if 'WGAN' in name:
        from modules.datgan import DATWGAN as LIB
    if any(x in name for x in ('WGANGP','WGGP')) :
        from modules.datgan import DATWGANGP as LIB
    elif 'SGAN' in name:
        from modules.datgan import DATSGAN as LIB
    else:
        from modules.datgan import DATWGAN as LIB


    model = LIB.load(input_folder + name + '/', 'trained')
# Out:
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\hooks.py:17: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\optimizer.py:18: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:20: The name tf.train.SessionCreator is deprecated. Please use tf.compat.v1.train.SessionCreator instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\varmanip.py:178: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\predict\config.py:101: The name tf.train.ChiefSessionCreator is deprecated. Please use tf.compat.v1.train.ChiefSessionCreator instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:41: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\graph_builder\model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\graph_builder\model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\tower.py:204: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\tower.py:216: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\tower.py:101: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\collection.py:33: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:483: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:484: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:199: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for age (in-edges: 0; ancestors: 0)
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:215: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [1111 16:35:58 @registry.py:126] gen/LSTM/age/FC input: [500, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\fc.py:57: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\fc.py:67: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# [1111 16:35:58 @registry.py:134] gen/LSTM/age/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/age/FC_val input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/age/FC_val output: [500, 5]
# [1111 16:35:58 @registry.py:126] gen/LSTM/age/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/age/FC_prob output: [500, 5]
# [1111 16:35:58 @registry.py:126] gen/LSTM/age/FC_input input: [500, 10]
# [1111 16:35:58 @registry.py:134] gen/LSTM/age/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for gender (in-edges: 0; ancestors: 0)
# [1111 16:35:58 @registry.py:126] gen/LSTM/gender/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/gender/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/gender/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/gender/FC_prob output: [500, 2]
# [1111 16:35:58 @registry.py:126] gen/LSTM/gender/FC_input input: [500, 2]
# [1111 16:35:58 @registry.py:134] gen/LSTM/gender/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for travel_dow (in-edges: 0; ancestors: 0)
# [1111 16:35:58 @registry.py:126] gen/LSTM/travel_dow/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/travel_dow/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/travel_dow/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/travel_dow/FC_prob output: [500, 7]
# [1111 16:35:58 @registry.py:126] gen/LSTM/travel_dow/FC_input input: [500, 7]
# [1111 16:35:58 @registry.py:134] gen/LSTM/travel_dow/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for license (in-edges: 1; ancestors: 1)
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:223: The name tf.nn.rnn_cell.LSTMStateTuple is deprecated. Please use tf.compat.v1.nn.rnn_cell.LSTMStateTuple instead.
#
# [1111 16:35:58 @registry.py:126] gen/LSTM/license/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/license/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/license/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/license/FC_prob output: [500, 2]
# [1111 16:35:58 @registry.py:126] gen/LSTM/license/FC_input input: [500, 2]
# [1111 16:35:58 @registry.py:134] gen/LSTM/license/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for education_level (in-edges: 1; ancestors: 1)
# [1111 16:35:58 @registry.py:126] gen/LSTM/education_level/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/education_level/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/education_level/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/education_level/FC_prob output: [500, 6]
# [1111 16:35:58 @registry.py:126] gen/LSTM/education_level/FC_input input: [500, 6]
# [1111 16:35:58 @registry.py:134] gen/LSTM/education_level/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for work_status (in-edges: 2; ancestors: 3)
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-work_status/FC_inputs input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-work_status/FC_inputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-work_status/FC_states input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-work_status/FC_states output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-work_status/FC_h_outputs input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-work_status/FC_h_outputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/work_status/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/work_status/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/work_status/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/work_status/FC_prob output: [500, 8]
# [1111 16:35:58 @registry.py:126] gen/LSTM/work_status/FC_input input: [500, 8]
# [1111 16:35:58 @registry.py:134] gen/LSTM/work_status/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for hh_income (in-edges: 2; ancestors: 4)
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_income/FC_inputs input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_income/FC_inputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_income/FC_states input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_income/FC_states output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_income/FC_h_outputs input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_income/FC_h_outputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_income/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_income/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_income/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_income/FC_prob output: [500, 7]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_income/FC_input input: [500, 7]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_income/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for trip_purpose (in-edges: 1; ancestors: 4)
# [1111 16:35:58 @registry.py:126] gen/LSTM/trip_purpose/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/trip_purpose/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/trip_purpose/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/trip_purpose/FC_prob output: [500, 7]
# [1111 16:35:58 @registry.py:126] gen/LSTM/trip_purpose/FC_input input: [500, 7]
# [1111 16:35:58 @registry.py:134] gen/LSTM/trip_purpose/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for hh_descr (in-edges: 2; ancestors: 5)
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_descr/FC_inputs input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_descr/FC_inputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_descr/FC_states input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_descr/FC_states output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_descr/FC_h_outputs input: [500, 200]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_descr/FC_h_outputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_descr/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_descr/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_descr/FC_prob input: [500, 50]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_descr/FC_prob output: [500, 4]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_descr/FC_input input: [500, 4]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_descr/FC_input output: [500, 100]
# [1111 16:35:58 @DATSGANModel.py:205] Creating cell for hh_size (in-edges: 3; ancestors: 5)
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_size/FC_inputs input: [500, 300]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_size/FC_inputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_size/FC_states input: [500, 300]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_size/FC_states output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/concat-hh_size/FC_h_outputs input: [500, 300]
# [1111 16:35:58 @registry.py:134] gen/LSTM/concat-hh_size/FC_h_outputs output: [500, 100]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_size/FC input: [500, 100]
# [1111 16:35:58 @registry.py:134] gen/LSTM/hh_size/FC output: [500, 50]
# [1111 16:35:58 @registry.py:126] gen/LSTM/hh_size/FC_prob input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_size/FC_prob output: [500, 8]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_size/FC_input input: [500, 8]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_size/FC_input output: [500, 100]
# [1111 16:35:59 @DATSGANModel.py:205] Creating cell for departure_time (in-edges: 1; ancestors: 5)
# [1111 16:35:59 @registry.py:126] gen/LSTM/departure_time/FC input: [500, 100]
# [1111 16:35:59 @registry.py:134] gen/LSTM/departure_time/FC output: [500, 50]
# [1111 16:35:59 @registry.py:126] gen/LSTM/departure_time/FC_val input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/departure_time/FC_val output: [500, 6]
# [1111 16:35:59 @registry.py:126] gen/LSTM/departure_time/FC_prob input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/departure_time/FC_prob output: [500, 6]
# [1111 16:35:59 @registry.py:126] gen/LSTM/departure_time/FC_input input: [500, 12]
# [1111 16:35:59 @registry.py:134] gen/LSTM/departure_time/FC_input output: [500, 100]
# [1111 16:35:59 @DATSGANModel.py:205] Creating cell for distance (in-edges: 1; ancestors: 5)
# [1111 16:35:59 @registry.py:126] gen/LSTM/distance/FC input: [500, 100]
# [1111 16:35:59 @registry.py:134] gen/LSTM/distance/FC output: [500, 50]
# [1111 16:35:59 @registry.py:126] gen/LSTM/distance/FC_val input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/distance/FC_val output: [500, 6]
# [1111 16:35:59 @registry.py:126] gen/LSTM/distance/FC_prob input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/distance/FC_prob output: [500, 6]
# [1111 16:35:59 @registry.py:126] gen/LSTM/distance/FC_input input: [500, 12]
# [1111 16:35:59 @registry.py:134] gen/LSTM/distance/FC_input output: [500, 100]
# [1111 16:35:59 @DATSGANModel.py:205] Creating cell for hh_vehicles (in-edges: 2; ancestors: 6)
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-hh_vehicles/FC_inputs input: [500, 200]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-hh_vehicles/FC_inputs output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-hh_vehicles/FC_states input: [500, 200]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-hh_vehicles/FC_states output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-hh_vehicles/FC_h_outputs input: [500, 200]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-hh_vehicles/FC_h_outputs output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_vehicles/FC input: [500, 100]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_vehicles/FC output: [500, 50]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_vehicles/FC_prob input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_vehicles/FC_prob output: [500, 9]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_vehicles/FC_input input: [500, 9]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_vehicles/FC_input output: [500, 100]
# [1111 16:35:59 @DATSGANModel.py:205] Creating cell for hh_bikes (in-edges: 2; ancestors: 6)
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-hh_bikes/FC_inputs input: [500, 200]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-hh_bikes/FC_inputs output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-hh_bikes/FC_states input: [500, 200]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-hh_bikes/FC_states output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-hh_bikes/FC_h_outputs input: [500, 200]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-hh_bikes/FC_h_outputs output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_bikes/FC input: [500, 100]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_bikes/FC output: [500, 50]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_bikes/FC_prob input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_bikes/FC_prob output: [500, 8]
# [1111 16:35:59 @registry.py:126] gen/LSTM/hh_bikes/FC_input input: [500, 8]
# [1111 16:35:59 @registry.py:134] gen/LSTM/hh_bikes/FC_input output: [500, 100]
# [1111 16:35:59 @DATSGANModel.py:205] Creating cell for choice (in-edges: 7; ancestors: 13)
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-choice/FC_inputs input: [500, 700]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-choice/FC_inputs output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-choice/FC_states input: [500, 700]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-choice/FC_states output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/concat-choice/FC_h_outputs input: [500, 700]
# [1111 16:35:59 @registry.py:134] gen/LSTM/concat-choice/FC_h_outputs output: [500, 100]
# [1111 16:35:59 @registry.py:126] gen/LSTM/choice/FC input: [500, 100]
# [1111 16:35:59 @registry.py:134] gen/LSTM/choice/FC output: [500, 50]
# [1111 16:35:59 @registry.py:126] gen/LSTM/choice/FC_prob input: [500, 50]
# [1111 16:35:59 @registry.py:134] gen/LSTM/choice/FC_prob output: [500, 5]
# [1111 16:35:59 @registry.py:126] gen/LSTM/choice/FC_input input: [500, 5]
# [1111 16:35:59 @registry.py:134] gen/LSTM/choice/FC_input output: [500, 100]
# [1111 16:35:59 @registry.py:126] discrim/DISCR_FC_0/FC input: [500, 107]
# [1111 16:35:59 @registry.py:134] discrim/DISCR_FC_0/FC output: [500, 100]
# [1111 16:35:59 @registry.py:126] discrim/DISCR_FC_0/FC_DIVERSITY input: [500, 100]
# [1111 16:35:59 @registry.py:134] discrim/DISCR_FC_0/FC_DIVERSITY output: [500, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\batch_norm.py:204: The name tf.layers.BatchNormalization is deprecated. Please use tf.compat.v1.layers.BatchNormalization instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\collection.py:45: The name tf.get_collection_ref is deprecated. Please use tf.compat.v1.get_collection_ref instead.
#
# [1111 16:35:59 @registry.py:126] discrim/DISCR_FC_TOP input: [500, 110]
# [1111 16:35:59 @registry.py:134] discrim/DISCR_FC_TOP output: [500, 1]
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:574: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:581: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# [1111 16:36:00 @collection.py:146] New collections created in tower : tf.GraphKeys.REGULARIZATION_LOSSES
# [1111 16:36:00 @collection.py:165] These collections were modified but restored in : (tf.GraphKeys.SUMMARIES: 0->2)
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sessinit.py:120: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sessinit.py:127: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# [1111 16:36:00 @sessinit.py:87] WRN The following variables are in the checkpoint, but not found in the graph: global_step, optimize/beta1_power, optimize/beta2_power
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sessinit.py:111: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [1111 16:36:01 @sessinit.py:114] Restoring checkpoint from ../output/Chicago/SGAN_OR/model\model-17000 ...
# INFO:tensorflow:Restoring parameters from ../output/Chicago/SGAN_OR/model\model-17000

# %%
samples = model.sample(len(df))
if dataset is 'Chicago':
    samples.age = np.round(samples.age)
elif dataset is 'LPMC':
    samples.age = np.round(samples.age)
    samples.distance = np.round(samples.distance)
samples.to_csv(output_folder + name + '_BO.csv', index=False)
# Out:
# [1111 16:36:02 @DATSGAN.py:269] Loading Preprocessor!
# |                                                                                          |17/?[00:01<00:00,15.60it/s]
