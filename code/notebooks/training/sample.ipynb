# %%
import os
os.chdir('../..')

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.9

# %%
import numpy as np
import pandas as pd
import json

import matplotlib.pyplot as plt

# For the Python notebook
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
dataset = 'LPMC'
name = 'WGAN3_WI'

# %%
df = pd.read_csv('../data/' + dataset + '/data.csv')

# %%
input_folder = '../output/' + dataset + '/'
output_folder = '../synth_data/' + dataset + '/'

# %%
if name not in os.listdir(input_folder):
    raise ValueError("Name of the model unknown!")

# %%
model = None
if name is 'CTGAN':
    import ctgan
    from ctgan import CTGANSynthesizer
    
    ctgan = CTGANSynthesizer()
    model = ctgan.load(input_folder + 'CTGAN/trained.pickle')
    
elif name is 'TGAN':
    from tgan.model import TGANModel
    model = TGANModel.load(input_folder + name + '/trained.pickle')
else:
    
    LIB = None
        
    if 'WGAN' in name:
        from modules.datgan import DATWGAN as LIB
    if any(x in name for x in ('WGANGP','WGGP')) :
        from modules.datgan import DATWGANGP as LIB
    elif 'SGAN' in name:
        from modules.datgan import DATSGAN as LIB
    else:
        from modules.datgan import DATWGAN as LIB


    model = LIB.load(input_folder + name + '/', 'trained')
# Out:
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\callbacks\hooks.py:17: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\optimizer.py:18: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sesscreate.py:20: The name tf.train.SessionCreator is deprecated. Please use tf.compat.v1.train.SessionCreator instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\varmanip.py:178: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\predict\config.py:101: The name tf.train.ChiefSessionCreator is deprecated. Please use tf.compat.v1.train.ChiefSessionCreator instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\common.py:41: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\graph_builder\model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\graph_builder\model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\tower.py:204: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\tower.py:216: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\tower.py:101: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\collection.py:33: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:482: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:483: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:199: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# [1120 19:54:12 @DATSGANModel.py:205] Creating cell for travel_year (in-edges: 0; ancestors: 0)
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:215: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_year/FC input: [500, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\fc.py:57: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\fc.py:67: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_year/FC output: [500, 50]
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_year/FC_prob input: [500, 50]
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_year/FC_prob output: [500, 4]
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_year/FC_input input: [500, 4]
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_year/FC_input output: [500, 100]
# [1120 19:54:12 @DATSGANModel.py:205] Creating cell for travel_date (in-edges: 0; ancestors: 0)
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_date/FC input: [500, 100]
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_date/FC output: [500, 50]
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_date/FC_prob input: [500, 50]
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_date/FC_prob output: [500, 31]
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_date/FC_input input: [500, 31]
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_date/FC_input output: [500, 100]
# [1120 19:54:12 @DATSGANModel.py:205] Creating cell for female (in-edges: 0; ancestors: 0)
# [1120 19:54:12 @registry.py:126] gen/LSTM/female/FC input: [500, 100]
# [1120 19:54:12 @registry.py:134] gen/LSTM/female/FC output: [500, 50]
# [1120 19:54:12 @registry.py:126] gen/LSTM/female/FC_prob input: [500, 50]
# [1120 19:54:12 @registry.py:134] gen/LSTM/female/FC_prob output: [500, 2]
# [1120 19:54:12 @registry.py:126] gen/LSTM/female/FC_input input: [500, 2]
# [1120 19:54:12 @registry.py:134] gen/LSTM/female/FC_input output: [500, 100]
# [1120 19:54:12 @DATSGANModel.py:205] Creating cell for age (in-edges: 0; ancestors: 0)
# [1120 19:54:12 @registry.py:126] gen/LSTM/age/FC input: [500, 100]
# [1120 19:54:12 @registry.py:134] gen/LSTM/age/FC output: [500, 50]
# [1120 19:54:12 @registry.py:126] gen/LSTM/age/FC_val input: [500, 50]
# [1120 19:54:12 @registry.py:134] gen/LSTM/age/FC_val output: [500, 6]
# [1120 19:54:12 @registry.py:126] gen/LSTM/age/FC_prob input: [500, 50]
# [1120 19:54:12 @registry.py:134] gen/LSTM/age/FC_prob output: [500, 6]
# [1120 19:54:12 @registry.py:126] gen/LSTM/age/FC_input input: [500, 12]
# [1120 19:54:12 @registry.py:134] gen/LSTM/age/FC_input output: [500, 100]
# [1120 19:54:12 @DATSGANModel.py:205] Creating cell for pt_n_interchanges (in-edges: 0; ancestors: 0)
# [1120 19:54:12 @registry.py:126] gen/LSTM/pt_n_interchanges/FC input: [500, 100]
# [1120 19:54:12 @registry.py:134] gen/LSTM/pt_n_interchanges/FC output: [500, 50]
# [1120 19:54:12 @registry.py:126] gen/LSTM/pt_n_interchanges/FC_prob input: [500, 50]
# [1120 19:54:12 @registry.py:134] gen/LSTM/pt_n_interchanges/FC_prob output: [500, 5]
# [1120 19:54:12 @registry.py:126] gen/LSTM/pt_n_interchanges/FC_input input: [500, 5]
# [1120 19:54:12 @registry.py:134] gen/LSTM/pt_n_interchanges/FC_input output: [500, 100]
# [1120 19:54:12 @DATSGANModel.py:205] Creating cell for travel_month (in-edges: 0; ancestors: 0)
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_month/FC input: [500, 100]
# [1120 19:54:12 @registry.py:134] gen/LSTM/travel_month/FC output: [500, 50]
# [1120 19:54:12 @registry.py:126] gen/LSTM/travel_month/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/travel_month/FC_prob output: [500, 12]
# [1120 19:54:13 @registry.py:126] gen/LSTM/travel_month/FC_input input: [500, 12]
# [1120 19:54:13 @registry.py:134] gen/LSTM/travel_month/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for survey_year (in-edges: 1; ancestors: 1)
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:223: The name tf.nn.rnn_cell.LSTMStateTuple is deprecated. Please use tf.compat.v1.nn.rnn_cell.LSTMStateTuple instead.
#
# [1120 19:54:13 @registry.py:126] gen/LSTM/survey_year/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/survey_year/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/survey_year/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/survey_year/FC_prob output: [500, 3]
# [1120 19:54:13 @registry.py:126] gen/LSTM/survey_year/FC_input input: [500, 3]
# [1120 19:54:13 @registry.py:134] gen/LSTM/survey_year/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for day_of_week (in-edges: 1; ancestors: 1)
# [1120 19:54:13 @registry.py:126] gen/LSTM/day_of_week/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/day_of_week/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/day_of_week/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/day_of_week/FC_prob output: [500, 7]
# [1120 19:54:13 @registry.py:126] gen/LSTM/day_of_week/FC_input input: [500, 7]
# [1120 19:54:13 @registry.py:134] gen/LSTM/day_of_week/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for driving_license (in-edges: 2; ancestors: 2)
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-driving_license/FC_inputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-driving_license/FC_inputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-driving_license/FC_states input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-driving_license/FC_states output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-driving_license/FC_h_outputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-driving_license/FC_h_outputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_license/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_license/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_license/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_license/FC_prob output: [500, 2]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_license/FC_input input: [500, 2]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_license/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for bus_scale (in-edges: 1; ancestors: 1)
# [1120 19:54:13 @registry.py:126] gen/LSTM/bus_scale/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/bus_scale/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/bus_scale/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/bus_scale/FC_prob output: [500, 3]
# [1120 19:54:13 @registry.py:126] gen/LSTM/bus_scale/FC_input input: [500, 3]
# [1120 19:54:13 @registry.py:134] gen/LSTM/bus_scale/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for faretype (in-edges: 1; ancestors: 1)
# [1120 19:54:13 @registry.py:126] gen/LSTM/faretype/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/faretype/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/faretype/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/faretype/FC_prob output: [500, 5]
# [1120 19:54:13 @registry.py:126] gen/LSTM/faretype/FC_input input: [500, 5]
# [1120 19:54:13 @registry.py:134] gen/LSTM/faretype/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for purpose (in-edges: 1; ancestors: 2)
# [1120 19:54:13 @registry.py:126] gen/LSTM/purpose/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/purpose/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/purpose/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/purpose/FC_prob output: [500, 5]
# [1120 19:54:13 @registry.py:126] gen/LSTM/purpose/FC_input input: [500, 5]
# [1120 19:54:13 @registry.py:134] gen/LSTM/purpose/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for car_ownership (in-edges: 2; ancestors: 3)
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-car_ownership/FC_inputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-car_ownership/FC_inputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-car_ownership/FC_states input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-car_ownership/FC_states output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-car_ownership/FC_h_outputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-car_ownership/FC_h_outputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/car_ownership/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/car_ownership/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/car_ownership/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/car_ownership/FC_prob output: [500, 3]
# [1120 19:54:13 @registry.py:126] gen/LSTM/car_ownership/FC_input input: [500, 3]
# [1120 19:54:13 @registry.py:134] gen/LSTM/car_ownership/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for start_time_linear (in-edges: 1; ancestors: 3)
# [1120 19:54:13 @registry.py:126] gen/LSTM/start_time_linear/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/start_time_linear/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/start_time_linear/FC_val input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/start_time_linear/FC_val output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/start_time_linear/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/start_time_linear/FC_prob output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/start_time_linear/FC_input input: [500, 12]
# [1120 19:54:13 @registry.py:134] gen/LSTM/start_time_linear/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for distance (in-edges: 1; ancestors: 3)
# [1120 19:54:13 @registry.py:126] gen/LSTM/distance/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/distance/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/distance/FC_val input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/distance/FC_val output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/distance/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/distance/FC_prob output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/distance/FC_input input: [500, 12]
# [1120 19:54:13 @registry.py:134] gen/LSTM/distance/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for fueltype (in-edges: 1; ancestors: 4)
# [1120 19:54:13 @registry.py:126] gen/LSTM/fueltype/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/fueltype/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/fueltype/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/fueltype/FC_prob output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/fueltype/FC_input input: [500, 6]
# [1120 19:54:13 @registry.py:134] gen/LSTM/fueltype/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for driving_traffic_percent (in-edges: 2; ancestors: 4)
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-driving_traffic_percent/FC_inputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-driving_traffic_percent/FC_inputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-driving_traffic_percent/FC_states input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-driving_traffic_percent/FC_states output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-driving_traffic_percent/FC_h_outputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-driving_traffic_percent/FC_h_outputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_traffic_percent/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_traffic_percent/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_traffic_percent/FC_val input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_traffic_percent/FC_val output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_traffic_percent/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_traffic_percent/FC_prob output: [500, 6]
# [1120 19:54:13 @registry.py:126] gen/LSTM/driving_traffic_percent/FC_input input: [500, 12]
# [1120 19:54:13 @registry.py:134] gen/LSTM/driving_traffic_percent/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for cost_driving_fuel (in-edges: 2; ancestors: 9)
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-cost_driving_fuel/FC_inputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-cost_driving_fuel/FC_inputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-cost_driving_fuel/FC_states input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-cost_driving_fuel/FC_states output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/concat-cost_driving_fuel/FC_h_outputs input: [500, 200]
# [1120 19:54:13 @registry.py:134] gen/LSTM/concat-cost_driving_fuel/FC_h_outputs output: [500, 100]
# [1120 19:54:13 @registry.py:126] gen/LSTM/cost_driving_fuel/FC input: [500, 100]
# [1120 19:54:13 @registry.py:134] gen/LSTM/cost_driving_fuel/FC output: [500, 50]
# [1120 19:54:13 @registry.py:126] gen/LSTM/cost_driving_fuel/FC_val input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/cost_driving_fuel/FC_val output: [500, 5]
# [1120 19:54:13 @registry.py:126] gen/LSTM/cost_driving_fuel/FC_prob input: [500, 50]
# [1120 19:54:13 @registry.py:134] gen/LSTM/cost_driving_fuel/FC_prob output: [500, 5]
# [1120 19:54:13 @registry.py:126] gen/LSTM/cost_driving_fuel/FC_input input: [500, 10]
# [1120 19:54:13 @registry.py:134] gen/LSTM/cost_driving_fuel/FC_input output: [500, 100]
# [1120 19:54:13 @DATSGANModel.py:205] Creating cell for dur_driving (in-edges: 1; ancestors: 4)
# [1120 19:54:13 @registry.py:126] gen/LSTM/dur_driving/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_driving/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_driving/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_driving/FC_val output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_driving/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_driving/FC_prob output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_driving/FC_input input: [500, 12]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_driving/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for dur_walking (in-edges: 1; ancestors: 4)
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_walking/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_walking/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_walking/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_walking/FC_val output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_walking/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_walking/FC_prob output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_walking/FC_input input: [500, 12]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_walking/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for dur_cycling (in-edges: 1; ancestors: 4)
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_cycling/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_cycling/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_cycling/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_cycling/FC_val output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_cycling/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_cycling/FC_prob output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_cycling/FC_input input: [500, 12]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_cycling/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for dur_pt_access (in-edges: 1; ancestors: 4)
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_access/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_access/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_access/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_access/FC_val output: [500, 5]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_access/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_access/FC_prob output: [500, 5]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_access/FC_input input: [500, 10]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_access/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for dur_pt_rail (in-edges: 1; ancestors: 4)
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_rail/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_rail/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_rail/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_rail/FC_val output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_rail/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_rail/FC_prob output: [500, 6]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_rail/FC_input input: [500, 12]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_rail/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for dur_pt_bus (in-edges: 1; ancestors: 4)
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_bus/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_bus/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_bus/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_bus/FC_val output: [500, 5]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_bus/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_bus/FC_prob output: [500, 5]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_bus/FC_input input: [500, 10]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_bus/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for dur_pt_int (in-edges: 2; ancestors: 5)
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-dur_pt_int/FC_inputs input: [500, 200]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-dur_pt_int/FC_inputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-dur_pt_int/FC_states input: [500, 200]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-dur_pt_int/FC_states output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-dur_pt_int/FC_h_outputs input: [500, 200]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-dur_pt_int/FC_h_outputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_int/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_int/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_int/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_int/FC_val output: [500, 5]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_int/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_int/FC_prob output: [500, 5]
# [1120 19:54:14 @registry.py:126] gen/LSTM/dur_pt_int/FC_input input: [500, 10]
# [1120 19:54:14 @registry.py:134] gen/LSTM/dur_pt_int/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for cost_driving_con_charge (in-edges: 5; ancestors: 10)
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-cost_driving_con_charge/FC_inputs input: [500, 500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-cost_driving_con_charge/FC_inputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-cost_driving_con_charge/FC_states input: [500, 500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-cost_driving_con_charge/FC_states output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-cost_driving_con_charge/FC_h_outputs input: [500, 500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-cost_driving_con_charge/FC_h_outputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_driving_con_charge/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_driving_con_charge/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_driving_con_charge/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_driving_con_charge/FC_prob output: [500, 2]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_driving_con_charge/FC_input input: [500, 2]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_driving_con_charge/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for cost_transit (in-edges: 5; ancestors: 10)
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-cost_transit/FC_inputs input: [500, 500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-cost_transit/FC_inputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-cost_transit/FC_states input: [500, 500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-cost_transit/FC_states output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-cost_transit/FC_h_outputs input: [500, 500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-cost_transit/FC_h_outputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_transit/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_transit/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_transit/FC_val input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_transit/FC_val output: [500, 8]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_transit/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_transit/FC_prob output: [500, 8]
# [1120 19:54:14 @registry.py:126] gen/LSTM/cost_transit/FC_input input: [500, 16]
# [1120 19:54:14 @registry.py:134] gen/LSTM/cost_transit/FC_input output: [500, 100]
# [1120 19:54:14 @DATSGANModel.py:205] Creating cell for travel_mode (in-edges: 15; ancestors: 24)
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-travel_mode/FC_inputs input: [500, 1500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-travel_mode/FC_inputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-travel_mode/FC_states input: [500, 1500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-travel_mode/FC_states output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/concat-travel_mode/FC_h_outputs input: [500, 1500]
# [1120 19:54:14 @registry.py:134] gen/LSTM/concat-travel_mode/FC_h_outputs output: [500, 100]
# [1120 19:54:14 @registry.py:126] gen/LSTM/travel_mode/FC input: [500, 100]
# [1120 19:54:14 @registry.py:134] gen/LSTM/travel_mode/FC output: [500, 50]
# [1120 19:54:14 @registry.py:126] gen/LSTM/travel_mode/FC_prob input: [500, 50]
# [1120 19:54:14 @registry.py:134] gen/LSTM/travel_mode/FC_prob output: [500, 4]
# [1120 19:54:14 @registry.py:126] gen/LSTM/travel_mode/FC_input input: [500, 4]
# [1120 19:54:14 @registry.py:134] gen/LSTM/travel_mode/FC_input output: [500, 100]
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:507: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\glede\Documents\EPFL\PhD\SynthPop\code\modules\datgan\models\DATSGANModel.py:443: The name tf.log is deprecated. Please use tf.math.log instead.
#
# [1120 19:54:15 @registry.py:126] discrim/DISCR_FC_0/FC input: [500, 246]
# [1120 19:54:15 @registry.py:134] discrim/DISCR_FC_0/FC output: [500, 100]
# [1120 19:54:15 @registry.py:126] discrim/DISCR_FC_0/FC_DIVERSITY input: [500, 100]
# [1120 19:54:15 @registry.py:134] discrim/DISCR_FC_0/FC_DIVERSITY output: [500, 100]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\models\batch_norm.py:204: The name tf.layers.BatchNormalization is deprecated. Please use tf.compat.v1.layers.BatchNormalization instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\collection.py:45: The name tf.get_collection_ref is deprecated. Please use tf.compat.v1.get_collection_ref instead.
#
# [1120 19:54:15 @registry.py:126] discrim/DISCR_FC_TOP input: [500, 110]
# [1120 19:54:15 @registry.py:134] discrim/DISCR_FC_TOP output: [500, 1]
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sessinit.py:120: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sessinit.py:127: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# [1120 19:54:15 @sessinit.py:87] WRN The following variables are in the checkpoint, but not found in the graph: global_step
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorpack\tfutils\sessinit.py:111: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From D:\Users\glede\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\ops\array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [1120 19:54:17 @sessinit.py:114] Restoring checkpoint from ../output/LPMC/WGAN3_WI/model\model-52499 ...
# INFO:tensorflow:Restoring parameters from ../output/LPMC/WGAN3_WI/model\model-52499

# %%
samples = model.sample(len(df), 'NO')
#samples = model.sample(len(df))
if dataset is 'Chicago':
    samples.age = np.round(samples.age)
elif dataset is 'LPMC':
    samples.age = np.round(samples.age)
    samples.distance = np.round(samples.distance)
samples.to_csv(output_folder + name + '_NO.csv', index=False)
# Out:
# [1120 19:55:06 @DATSGAN.py:266] Loading Preprocessor!
# |                                                                                          |35/?[00:02<00:00,13.13it/s]
